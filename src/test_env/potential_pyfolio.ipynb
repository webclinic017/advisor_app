# %%
# silence warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import yfinance as yf
import pyfolio as pf
# %matplotlib inline

# %%
fb = yf.Ticker('FB')
history = fb.history('max')
history.index = history.index.tz_localize('utc')

# %%
returns = history.Close.pct_change()

# %%
pf.create_returns_tear_sheet(returns, live_start_date='2020-1-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2012-05-18</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2021-09-24</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>91</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>20</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>24.723%</td>
#       <td>36.7%</td>
#       <td>26.864%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>436.882%</td>
#       <td>71.966%</td>
#       <td>823.254%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>36.174%</td>
#       <td>39.545%</td>
#       <td>36.816%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.79</td>
#       <td>0.99</td>
#       <td>0.83</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.46</td>
#       <td>1.06</td>
#       <td>0.50</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.88</td>
#       <td>0.82</td>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-53.623%</td>
#       <td>-34.592%</td>
#       <td>-53.623%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.17</td>
#       <td>1.19</td>
#       <td>1.17</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.21</td>
#       <td>1.46</td>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#       <td>-0.13</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#       <td>4.20</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.07</td>
#       <td>1.13</td>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-4.444%</td>
#       <td>-4.827%</td>
#       <td>-4.517%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>53.62</td>
#       <td>2012-05-18</td>
#       <td>2012-09-04</td>
#       <td>2013-08-05</td>
#       <td>317</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>42.96</td>
#       <td>2018-07-25</td>
#       <td>2018-12-24</td>
#       <td>2020-01-09</td>
#       <td>382</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>34.59</td>
#       <td>2020-01-29</td>
#       <td>2020-03-16</td>
#       <td>2020-05-20</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>22.06</td>
#       <td>2014-03-10</td>
#       <td>2014-04-28</td>
#       <td>2014-07-24</td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>21.17</td>
#       <td>2018-02-01</td>
#       <td>2018-03-27</td>
#       <td>2018-06-01</td>
#       <td>87</td>
#     </tr>
#   </tbody>
# </table>

# %%
# silence warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pyfolio as pf
import pandas as pd
# %matplotlib inline
import gzip
import os
