# %%
import os
import pickle
# Gmail API utils
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
# for encoding/decoding messages in base64
from base64 import urlsafe_b64decode, urlsafe_b64encode
# for dealing with attachement MIME types
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from mimetypes import guess_type as guess_mime_type

# %%
# Request all access (permission to read/send/receive emails, manage the inbox, and more)
SCOPES = ['https://mail.google.com/']
our_email = 'gordon.pisciotta@gmail.com'

# %%
def gmail_authenticate():
    creds = None
    # the file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first time
    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as token:
            creds = pickle.load(token)
    # if there are no (valid) credentials availablle, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # save the credentials for the next run
        with open("token.pickle", "wb") as token:
            pickle.dump(creds, token)
    return build('gmail', 'v1', credentials=creds)

# %%
# get the Gmail API service
service = gmail_authenticate()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b67a9f61fc0f> in <module>
#       1 # get the Gmail API service
# ----> 2 service = gmail_authenticate()
#
# <ipython-input-17-612e77092d7f> in gmail_authenticate()
#      12         else:
#      13             # flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
# ---> 14             flow = InstalledAppFlow.from_client_secrets_file('emailer-011235813-cff986204745.json', SCOPES)
#      15
#      16
#
# ~/anaconda3/envs/roy/lib/python3.7/site-packages/google_auth_oauthlib/flow.py in from_client_secrets_file(cls, client_secrets_file, scopes, **kwargs)
#     204             client_config = json.load(json_file)
#     205
# --> 206         return cls.from_client_config(client_config, scopes=scopes, **kwargs)
#     207
#     208     @property
#
# ~/anaconda3/envs/roy/lib/python3.7/site-packages/google_auth_oauthlib/flow.py in from_client_config(cls, client_config, scopes, **kwargs)
#     162             client_type = "installed"
#     163         else:
# --> 164             raise ValueError("Client secrets must be for a web or installed app.")
#     165
#     166         # these args cannot be passed to requests_oauthlib.OAuth2Session
#
# ValueError: Client secrets must be for a web or installed app.

# %%
# Adds the attachment with the given filename to the given message
def add_attachment(message, filename):
    content_type, encoding = guess_mime_type(filename)
    if content_type is None or encoding is not None:
        content_type = 'application/octet-stream'
    main_type, sub_type = content_type.split('/', 1)
    if main_type == 'text':
        fp = open(filename, 'rb')
        msg = MIMEText(fp.read().decode(), _subtype=sub_type)
        fp.close()
    elif main_type == 'image':
        fp = open(filename, 'rb')
        msg = MIMEImage(fp.read(), _subtype=sub_type)
        fp.close()
    elif main_type == 'audio':
        fp = open(filename, 'rb')
        msg = MIMEAudio(fp.read(), _subtype=sub_type)
        fp.close()
    else:
        fp = open(filename, 'rb')
        msg = MIMEBase(main_type, sub_type)
        msg.set_payload(fp.read())
        fp.close()
    filename = os.path.basename(filename)
    msg.add_header('Content-Disposition', 'attachment', filename=filename)
    message.attach(msg)

def build_message(destination, obj, body, attachments=[]):
    if not attachments: # no attachments given
        message = MIMEText(body)
        message['to'] = destination
        message['from'] = our_email
        message['subject'] = obj
    else:
        message = MIMEMultipart()
        message['to'] = destination
        message['from'] = our_email
        message['subject'] = obj
        message.attach(MIMEText(body))
        for filename in attachments:
            add_attachment(message, filename)
    return {'raw': urlsafe_b64encode(message.as_bytes()).decode()}

def send_message(service, destination, obj, body, attachments=[]):
    return service.users().messages().send(
      userId="me",
      body=build_message(destination, obj, body, attachments)
    ).execute()

# %%
# test send email
send_message(
    service, 
    "gordon.d.pisciotta@gmail.com", 
    "Recommended Stocks", 
    "Here are today's recommended stocks", 
    [
        "/home/gordon/gordon/portfolio/portfolio_app/data/recommenders/2021-07-27/recommender_final_return_dataFrame.pkl",
        "/home/gordon/gordon/portfolio/portfolio_app/data/recommenders/2021-07-27/recommender_00_return_dataFrame.pkl"
        # "credentials.json"
    ]
)
# Out:
# {'id': '17ae8e7fdd433d92',
#  'threadId': '17ae8e7fdd433d92',
#  'labelIds': ['Label_20', 'SENT', 'INBOX']}

# %%
def search_messages(service, query):
    result = service.users().messages().list(userId='me',q=query).execute()
    messages = [ ]
    if 'messages' in result:
        messages.extend(result['messages'])
    while 'nextPageToken' in result:
        page_token = result['nextPageToken']
        result = service.users().messages().list(userId='me',q=query, pageToken=page_token).execute()
        if 'messages' in result:
            messages.extend(result['messages'])
    return messages

# %%
# utility functions
def get_size_format(b, factor=1024, suffix="B"):
    """
    Scale bytes to its proper byte format
    e.g:
        1253656 => '1.20MB'
        1253656678 => '1.17GB'
    """
    for unit in ["", "K", "M", "G", "T", "P", "E", "Z"]:
        if b < factor:
            return f"{b:.2f}{unit}{suffix}"
        b /= factor
    return f"{b:.2f}Y{suffix}"


def clean(text):
    # clean text for creating a folder
    return "".join(c if c.isalnum() else "_" for c in text)

# %%
def parse_parts(service, parts, folder_name):
    """
    Utility function that parses the content of an email partition
    """
    if parts:
        for part in parts:
            filename = part.get("filename")
            mimeType = part.get("mimeType")
            body = part.get("body")
            data = body.get("data")
            file_size = body.get("size")
            part_headers = part.get("headers")
            if part.get("parts"):
                # recursively call this function when we see that a part
                # has parts inside
                parse_parts(service, part.get("parts"), folder_name)
            if mimeType == "text/plain":
                # if the email part is text plain
                if data:
                    text = urlsafe_b64decode(data).decode()
                    print(text)
            elif mimeType == "text/html":
                # if the email part is an HTML content
                # save the HTML file and optionally open it in the browser
                if not filename:
                    filename = "index.html"
                filepath = os.path.join(folder_name, filename)
                print("Saving HTML to", filepath)
                with open(filepath, "wb") as f:
                    f.write(urlsafe_b64decode(data))
            else:
                # attachment other than a plain text or HTML
                for part_header in part_headers:
                    part_header_name = part_header.get("name")
                    part_header_value = part_header.get("value")
                    if part_header_name == "Content-Disposition":
                        if "attachment" in part_header_value:
                            # we get the attachment ID 
                            # and make another request to get the attachment itself
                            print("Saving the file:", filename, "size:", get_size_format(file_size))
                            attachment_id = body.get("attachmentId")
                            attachment = service.users().messages() \
                                        .attachments().get(id=attachment_id, userId='me', messageId=msg['id']).execute()
                            data = attachment.get("data")
                            filepath = os.path.join(folder_name, filename)
                            if data:
                                with open(filepath, "wb") as f:
                                    f.write(urlsafe_b64decode(data))                      


def read_message(service, message_id):
    """
    This function takes Gmail API `service` and the given `message_id` and does the following:
        - Downloads the content of the email
        - Prints email basic information (To, From, Subject & Date) and plain/text parts
        - Creates a folder for each email based on the subject
        - Downloads text/html content (if available) and saves it under the folder created as index.html
        - Downloads any file that is attached to the email and saves it in the folder created
    """
    msg = service.users().messages().get(userId='me', id=message_id['id'], format='full').execute()
    # parts can be the message body, or attachments
    payload = msg['payload']
    headers = payload.get("headers")
    parts = payload.get("parts")
    folder_name = "email"
    if headers:
        # this section prints email basic info & creates a folder for the email
        for header in headers:
            name = header.get("name")
            value = header.get("value")
            if name == 'From':
                # we print the From address
                print("From:", value)
            if name == "To":
                # we print the To address
                print("To:", value)
            if name == "Subject":
                # make a directory with the name of the subject
                folder_name = clean(value)
                # we will also handle emails with the same subject name
                folder_counter = 0
                while os.path.isdir(folder_name):
                    folder_counter += 1
                    # we have the same folder name, add a number next to it
                    if folder_name[-1].isdigit() and folder_name[-2] == "_":
                        folder_name = f"{folder_name[:-2]}_{folder_counter}"
                    elif folder_name[-2:].isdigit() and folder_name[-3] == "_":
                        folder_name = f"{folder_name[:-3]}_{folder_counter}"
                    else:
                        folder_name = f"{folder_name}_{folder_counter}"
                os.mkdir(folder_name)
                print("Subject:", value)
            if name == "Date":
                # we print the date when the message was sent
                print("Date:", value)
        
    parse_parts(service, parts, folder_name)
    print("="*10)

# %%
# get emails that match the query you specify
results = search_messages(
    service, 
    "Career"
    )
    
# for each email matched, read it (output plain/text to console & save HTML and attachments)
for msg in results:
    read_message(service, msg)
# Out:
# Subject: How to Ignore the Noise
# Date: Tue, 27 Jul 2021 12:46:38 -0400
# To: gordon.pisciotta@gmail.com
# From: Motley Fool Stock Advisor <fool@foolcs.com>
# ==========
# To: Gordon Pisciotta <gordon.pisciotta@gmail.com>
# Date: Mon, 26 Jul 2021 18:56:17 +0000
# Subject: Take Home the Gold 🏅
# From: Profit Trends <profittrends@mb.profittrends.com>
# The Olympic Games are a major tailwind for the sports betting market. Here are the best ways to profit off this industry. ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
#
# [Profit Trends](https://events-b.mb.profittrends.com/z/rqa3oq5cm?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=1)
#
# SPONSORED
#
# [FREE Training Session From Investing Pro (and a Chance to Join Him in a New Venture)](https://events-b.mb.profittrends.com/track?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&bsft_aaid=8ded4280-4fc0-4ca7-9e5e-618112d23921&eid=d419dd7c-754d-4430-a369-866066237eaa&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=2&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&a=click&redir=https%3A%2F%2Fpro.oxfordclub.com%2Fm%2F1835154%3FcustomerNumber%3D000123491348%26campaignId%3D06dd6761-f5ce-4fdf-a673-0b7cf3ba19e1%26r%3Deml%26experimentId%3Dd419dd7c-754d-4430-a369-866066237eaa%26vid%3DR0pT2M%26customerId%3D000123491348-000118635230%26utm_campaign%3D20210726_pt_ore%26utm_source%3Dblueshift%26utm_medium%3Demail%26utm_content%3D20210726_pt_ore)
#
# [Shaking Hands City Night](https://events-b.mb.profittrends.com/track?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&bsft_aaid=8ded4280-4fc0-4ca7-9e5e-618112d23921&eid=d419dd7c-754d-4430-a369-866066237eaa&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=3&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&a=click&redir=https%3A%2F%2Fpro.oxfordclub.com%2Fm%2F1835154%3FcustomerNumber%3D000123491348%26campaignId%3D06dd6761-f5ce-4fdf-a673-0b7cf3ba19e1%26r%3Deml%26experimentId%3Dd419dd7c-754d-4430-a369-866066237eaa%26vid%3DR0pT2M%26customerId%3D000123491348-000118635230%26utm_campaign%3D20210726_pt_ore%26utm_source%3Dblueshift%26utm_medium%3Demail%26utm_content%3D20210726_pt_ore)
#
# He walks you through the trading process for his favorite strategy right now - right on camera!
#
# [Click here to discover the BEST strategy for current markets.](https://events-b.mb.profittrends.com/track?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&bsft_aaid=8ded4280-4fc0-4ca7-9e5e-618112d23921&eid=d419dd7c-754d-4430-a369-866066237eaa&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=4&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&a=click&redir=https%3A%2F%2Fpro.oxfordclub.com%2Fm%2F1835154%3FcustomerNumber%3D000123491348%26campaignId%3D06dd6761-f5ce-4fdf-a673-0b7cf3ba19e1%26r%3Deml%26experimentId%3Dd419dd7c-754d-4430-a369-866066237eaa%26vid%3DR0pT2M%26customerId%3D000123491348-000118635230%26utm_campaign%3D20210726_pt_ore%26utm_source%3Dblueshift%26utm_medium%3Demail%26utm_content%3D20210726_pt_ore)
#
# [MARKET TRENDS](https://events-b.mb.profittrends.com/z/q004gw5rc?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=5)
#
# How to Profit From the Tokyo Olympics
#
# Matthew Carr | Chief Trends Strategist | The Oxford Club
#
# [Matthew Carr]
# I operate by a really simple idea: The trend is your friend.
#
# I've built a career - and fortune - zeroing in on not only the [hottest trends](https://events-b.mb.profittrends.com/z/acosiy3p1?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=6) in the markets but also the tried-and-true cyclical trends. The ones that you can count on year after year.
#
# Well, one of my favorite cyclical trends to bank on every four years was delayed due to the pandemic. It has historically provided a boost to everything from clothes to sneakers and even food.
#
# Now, even though this massive event was delayed, it's offering a new booming opportunity that investors should be paying attention to... especially if they're looking to add a little sparkle to their portfolios over the next several weeks.
#
# $20.2 Billion Sprint
#
# In 2018, the U.S. Supreme Court struck down the Professional and Amateur Sports Protection Act (PASPA) of 1992 as unconstitutional.
#
# For more than two decades, this made sports betting largely illegal across the U.S.
#
# But the demise of PASPA set the stage for the greatest expansion of gaming in 20 years.
#
# Today, 25 states have commercial gaming operations in place. And 35% of Americans live in states where [sports betting](https://events-b.mb.profittrends.com/z/et9056psy?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=7) is now legal.
#
# [Legal Gaming in U.S.]
#
# This opportunity is expected to rapidly expand from here.
#
# Now, total American gaming revenue was in the toilet last year due to traditional casinos being closed. But sports betting grew nearly 70% to $1.53 billion, and online gaming revenue surged 198.9% to $1.55 billion.
#
# And the numbers are looking even better this year.
#
# [U.S. Monthly Sports Betting and iGaming Revenue]
#
# At the moment, mobile and online gaming - or iGaming - and sports betting account for 12.5% of U.S. commercial gaming revenue.
#
# iGaming is gaining traction as basically every jurisdiction in the country is looking for ways to raise revenue.
#
# Through the first five months of 2021, U.S. gaming revenue totaled $20.21 billion - a 13% increase over 2019. Plus, 16 of the 25 commercial gaming states are seeing revenues exceed those of 2019 - as first quarter revenue for the industry was the highest ever reported.
#
# Now - thanks to a popular catalyst - we're likely about to see sports betting revenue really vault higher.
#
# SPONSORED
#
# [Alexander Green Special Broadcast: The #1 Tech IPO for 2021](https://events-b.mb.profittrends.com/track?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&bsft_aaid=8ded4280-4fc0-4ca7-9e5e-618112d23921&eid=d419dd7c-754d-4430-a369-866066237eaa&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=8&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&a=click&redir=https%3A%2F%2Fpro.oxfordclub.com%2Fm%2F1835158%3FcustomerNumber%3D000123491348%26campaignId%3D06dd6761-f5ce-4fdf-a673-0b7cf3ba19e1%26r%3Deml%26experimentId%3Dd419dd7c-754d-4430-a369-866066237eaa%26vid%3DR0pT2M%26customerId%3D000123491348-000118635230%26utm_campaign%3D20210726_pt_ore%26utm_source%3Dblueshift%26utm_medium%3Demail%26utm_content%3D20210726_pt_ore)
#
# The fastest-growing software company in HISTORY... just went public. And Alex believes it could be the next tech superstar. [Click here to get the details.](https://events-b.mb.profittrends.com/track?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&bsft_aaid=8ded4280-4fc0-4ca7-9e5e-618112d23921&eid=d419dd7c-754d-4430-a369-866066237eaa&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=9&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&a=click&redir=https%3A%2F%2Fpro.oxfordclub.com%2Fm%2F1835158%3FcustomerNumber%3D000123491348%26campaignId%3D06dd6761-f5ce-4fdf-a673-0b7cf3ba19e1%26r%3Deml%26experimentId%3Dd419dd7c-754d-4430-a369-866066237eaa%26vid%3DR0pT2M%26customerId%3D000123491348-000118635230%26utm_campaign%3D20210726_pt_ore%26utm_source%3Dblueshift%26utm_medium%3Demail%26utm_content%3D20210726_pt_ore)
#
# A $227 Billion Marathon
#
# The global casino and online gambling market is worth $227 billion.
#
# And on Friday, one of the largest international sporting events kicked off - the Tokyo Olympics.
#
# But beyond all the fanfare and rooting for countries and favorite athletes, there's another storyline brewing. And it has nothing to do with the pandemic or politics.
#
# At least 20 million Americans plan to place bets on the Tokyo Olympics. That's roughly 8% of all adults in this country.
#
# About 45% of those adults plan to place wagers on basketball, followed by the 34% of adults who plan to bet on soccer.
#
# But most importantly, 43% will place bets online.
#
# That's an excellent opportunity for the likes of DraftKings (Nasdaq: DKNG) and Penn National Gaming (Nasdaq: PENN).
#
# These two companies have the largest presence in the iGaming sector.
#
# DraftKings originally started out as a fantasy sports platform. But it's been able to pivot and capture an enormous share of the online sports betting market in the U.S., particularly in the massive New Jersey market.
#
# Currently, 15 states have legalized online sports betting. DraftKings is present in 12 of them. Another six states have legalized iGaming. Of those, the company has a foothold in four.
#
# Penn National Gaming owns, operates or has a stake in 41 gaming and racing properties in 19 states. It has more than 50,000 gaming machines, 1,300 table games and 8,800 hotel rooms.
#
# It also offers live sports betting at its properties in Colorado, Illinois, Indiana, Iowa, Michigan, Mississippi, Pennsylvania and West Virginia.
#
# And in 2020, the company made a big splash into the [digital](https://events-b.mb.profittrends.com/z/iuamuq608?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=10) side of gaming by acquiring a 36% stake in Barstool Sports for $163 million. Over three years, Penn will increase its stake to 50%. This allows the casino operator to leverage Barstool's brand and platform for online and retail sports betting as well as iGaming.
#
# It's a no-brainer... Whenever there's a major sporting event, especially a global one, we see sports betting and iGaming revenue surge. And the best way investors can take home the gold this Olympics is by betting on this booming trend.
#
# Here's to high returns,
#
# Matthew
#
# [Leave a Comment](https://events-b.mb.profittrends.com/z/9qtbuzacs?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=11)
#
# MORE FROM PROFIT TRENDS
#
# [The $300 Billion Opportunity Behind This Market](https://events-b.mb.profittrends.com/z/017z5rrj0?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=12)
#
# [The Three Hottest Technologies to Invest in Today](https://events-b.mb.profittrends.com/z/acosiy3p1?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=13)
#
# [Are Oil and Gas Stocks Still Good Investments?](https://events-b.mb.profittrends.com/z/dyykgbwrv?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=14)
#
# [Facebook](https://events-b.mb.profittrends.com/z/j9w8s50fp?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=15)
# [Facebook](https://events-b.mb.profittrends.com/z/j9w8s50fp?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=16)
# [Twitter](https://events-b.mb.profittrends.com/z/wnms339it?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=17)
# [Twitter](https://events-b.mb.profittrends.com/z/wnms339it?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=18)
# [Email Share](mailto:?subject=A%20great%20piece%20from%20Profit%20Trends...&body=From%20Profit%20Trends:%0D%0A%0D%0AThe%20Olympic%20Games%20are%20a%20major%20tailwind%20for%20the%20sports%20betting%20market.%20Here%20are%20the%20best%20ways%20to%20profit%20off%20this%20industry.%0D%0A%0Dhttps://profittrends.com/market-trends/alternative-investments/how-to-profit-from-the-tokyo-olympics/?src=shared)
# [Email Share](mailto:?subject=A%20great%20piece%20from%20Profit%20Trends...&body=From%20Profit%20Trends:%0D%0A%0D%0AThe%20Olympic%20Games%20are%20a%20major%20tailwind%20for%20the%20sports%20betting%20market.%20Here%20are%20the%20best%20ways%20to%20profit%20off%20this%20industry.%0D%0A%0Dhttps://profittrends.com/market-trends/alternative-investments/how-to-profit-from-the-tokyo-olympics/?src=shared)
#
# SPONSORED
#
# [This Microcap Is Now Growing Faster Than Apple, Google, Amazon and Netflix... COMBINED](https://events-b.mb.profittrends.com/track?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&bsft_aaid=8ded4280-4fc0-4ca7-9e5e-618112d23921&eid=d419dd7c-754d-4430-a369-866066237eaa&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=21&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&a=click&redir=https%3A%2F%2Fpro.oxfordclub.com%2Fm%2F1835159%3FcustomerNumber%3D000123491348%26campaignId%3D06dd6761-f5ce-4fdf-a673-0b7cf3ba19e1%26r%3Deml%26experimentId%3Dd419dd7c-754d-4430-a369-866066237eaa%26vid%3DR0pT2M%26customerId%3D000123491348-000118635230%26utm_campaign%3D20210726_pt_ore%26utm_source%3Dblueshift%26utm_medium%3Demail%26utm_content%3D20210726_pt_ore)
#
# What's truly incredible is it trades at $4 a share and virtually NO MEDIA COVERAGE has even gotten to it!
#
# This is probably the last time this stock will ever trade this cheap again.
#
# [CLICK HERE TO GET THE DETAILS](https://events-b.mb.profittrends.com/track?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&bsft_aaid=8ded4280-4fc0-4ca7-9e5e-618112d23921&eid=d419dd7c-754d-4430-a369-866066237eaa&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=22&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&a=click&redir=https%3A%2F%2Fpro.oxfordclub.com%2Fm%2F1835159%3FcustomerNumber%3D000123491348%26campaignId%3D06dd6761-f5ce-4fdf-a673-0b7cf3ba19e1%26r%3Deml%26experimentId%3Dd419dd7c-754d-4430-a369-866066237eaa%26vid%3DR0pT2M%26customerId%3D000123491348-000118635230%26utm_campaign%3D20210726_pt_ore%26utm_source%3Dblueshift%26utm_medium%3Demail%26utm_content%3D20210726_pt_ore)
#
# [The Oxford Club]
#
# You are receiving this email because you subscribed to Profit Trends.
# Profit Trends is published by The Oxford Club.
# Ready to start investing? [Click here now.](https://events-b.mb.profittrends.com/z/9qmugyqic?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=23)
# Questions? Check out our [FAQs](https://events-b.mb.profittrends.com/z/ygymbvzef?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=24). Trying to reach us? [Contact us here.](https://events-b.mb.profittrends.com/z/onr3edii1?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=25)
#
# Please do not reply to this email as it goes to an unmonitored inbox.
#
# [Privacy Policy](https://events-b.mb.profittrends.com/z/u93z08cfq?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=26) | [Whitelist Profit Trends](https://events-b.mb.profittrends.com/z/z4i3dwp1d?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=27) | [Unsubscribe](https://events-b.mb.profittrends.com/track?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&bsft_aaid=8ded4280-4fc0-4ca7-9e5e-618112d23921&eid=d419dd7c-754d-4430-a369-866066237eaa&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=28&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&a=click&redir=https%3A%2F%2Fpreferences.oxfordclub.com%2F%3Ftype%3Dstandardunsub%26list%3DPROFTRND%252CPTDED%26utm_campaign%3D20210726_pt_ore%26utm_source%3Dblueshift%26utm_medium%3Demail%26utm_content%3D20210726_pt_ore)
#
# © 2021 The Oxford Club, LLC All Rights Reserved
# The Oxford Club | [105 West Monument Street](#) | [Baltimore, MD 21201](#)
# North America: [1.800.589.3430](#) | International: [+1.443.353.4334](#) | Fax: [1.410.329.1923](#)
# [Oxfordclub.com](https://events-b.mb.profittrends.com/z/d3s5zwszd?uid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7&mid=ddaef1f3-4bc7-4c86-ae56-b6fb062920c1&utid=68ce19a1-ce70-44f7-bbf7-121b7ed73ad7-PROFTRND&bsft_ek=2021-07-26T18%3A32%3A48Z&bsft_mime_type=text&bsft_tv=3&bsft_lx=34)
#
# The Oxford Club is a financial publisher that does not offer any personal financial advice or advocate the purchase or sale of any security or investment for any specific individual. Members should be aware that although our track record is highly rated by an independent analysis and has been legally reviewed, investment markets have inherent risks and there can be no guarantee of future profits. The stated returns may also include option trades.
#
# We expressly forbid our writers from having a financial interest in their own securities recommendations to readers. All of our employees and agents must wait 24 hours after online publication or 72 hours after the mailing of printed-only publications prior to following an initial recommendation. Any investments recommended by The Oxford Club should be made only after consulting with your investment advisor and only after reviewing the prospectus or financial statements of the company.
#
# Protected by copyright laws of the United States and international treaties. The information found on this website may only be used pursuant to the membership or subscription agreement and any reproduction, copying, or redistribution (electronic or otherwise, including on the world wide web), in whole or in part, is strictly prohibited without the express written permission of The Oxford Club, 105 W. Monument Street, Baltimore MD 21201.
# []
# Saving HTML to Take_Home_the_Gold__/index.html
# ==========
# Date: Sun, 25 Jul 2021 15:00:46 -0400 (EDT)
# From: Workshops at GA <hello@hello.generalassemb.ly>
# To: Gordon Pisciotta <gordon.pisciotta@gmail.com>
# Subject: Intro to customer journey mapping, securing financial safety, women in tech breakfast
# Coming up online!  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
#
# <https://link.generalassemb.ly/click/24529138.>
# About Us <https://link.generalassemb.ly/click/24529138.>     Browse Courses <https://link.generalassemb.ly/click/24529138.>     Get Matched <https://link.generalassemb.ly/click/24529138.>
#
#
#
# Intro to Customer Journey Mapping
#
# <https://link.generalassemb.ly/click/24529138.>
#
# Consumer empathy: It’s the key to successful product strategy, design, and marketing. In this free two-hour workshop, learn how customer journey mapping can dramatically shift behavior, organically generate habitual engagement, and promote a profitable viral cycle—no matter your line of work. You’ll walk away knowing how to implement consumer journey maps based on real business case studies.
#
# Get a Free Ticket Arrow <https://link.generalassemb.ly/click/24529138.>
#
# How to Secure Financial Safety
#
# Learn More Arrow <https://link.generalassemb.ly/click/24529138.>
#
# Intro to Data Analytics
#
# Join Us Arrow <https://link.generalassemb.ly/click/24529138.>
#
# Skill Up in Digital Marketing in 10 Weeks (or 1)
#
# Learn More Arrow <https://link.generalassemb.ly/click/24529138.>
#
# Ask Us Anything: How to Become a Job-Ready Software Engineer in 12 Weeks
#
# Check It Out Arrow <https://link.generalassemb.ly/click/24529138.>
#
# Query Me This: SQL Bootcamp
#
# Learn More Arrow <https://link.generalassemb.ly/click/24529138.>
#
# MIXCLOUD Presents Women In Tech
#
# You Can Do It Arrow <https://link.generalassemb.ly/click/24529138.85597/aHR0cHM6Ly9nZW5lcmFsYXNzZW1iLmx5L2VkdWNhdGlvbi9taXhjbG91ZC1wcmVzZW50cy13b21lbi1pbi10ZWNoL29ubGluZS8xOTA0ODg_dXRtX21lZGl1bT1lbWFpbCZ1dG1fc291cmNlPW5ld3NsZXR0ZXImdXRtX2NhbXBhaWduPTIwMjEtMDctMjUlMjBbdXMtd2VzdC1jYW5dJTIwV2Vla2x5JTIwTmV3c2xldHRlciZ1dG1fY29udGVudD1tYXJrZXRpbmcmdXRtX3Rlcm09MjQ1MjkxMzg/5f1ed0866577643680212e36C64feef4c>
#
#
#
# Upcoming Evening Courses & Full-Time Career Accelerators
#
# MARKETING
#
# Digital Marketing <https://link.generalassemb.ly/click/24529138.>
#
# DESIGN
#
# User Experience Design <https://link.generalassemb.ly/click/24529138.> User Experience Design career accelerator <https://link.generalassemb.ly/click/24529138.> Visual Design <https://link.generalassemb.ly/click/24529138.>
#
# CODING
#
# Front-End Web Development <https://link.generalassemb.ly/click/24529138.> JavaScript Development <https://link.generalassemb.ly/click/24529138.> Web Development career accelerator <https://link.generalassemb.ly/click/24529138.>
#
# DATA
#
# Data Analytics <https://link.generalassemb.ly/click/24529138.> Data Science <https://link.generalassemb.ly/click/24529138.85597/aHR0cHM6Ly9nZW5lcmFsYXNzZW1iLmx5L2VkdWNhdGlvbi9kYXRhLXNjaWVuY2U_cmVxdWVzdF9zeWxsYWJ1cz10cnVlJnV0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1uZXdzbGV0dGVyJnV0bV9jYW1wYWlnbj0yMDIxLTA3LTI1JTIwW3VzLXdlc3QtY2FuXSUyMFdlZWtseSUyME5ld3NsZXR0ZXImdXRtX2NvbnRlbnQ9bWFya2V0aW5nJnV0bV90ZXJtPTI0NTI5MTM4/5f1ed0866577643680212e36Cec55c3a4> Data Science career accelerator <https://link.generalassemb.ly/click/24529138.>
#
# BUSINESS
#
# Product Management <https://link.generalassemb.ly/click/24529138.85597/aHR0cHM6Ly9nZW5lcmFsYXNzZW1iLmx5L2VkdWNhdGlvbi9wcm9kdWN0LW1hbmFnZW1lbnQ_cmVxdWVzdF9zeWxsYWJ1cz10cnVlJnV0bV9tZWRpdW09ZW1haWwmdXRtX3NvdXJjZT1uZXdzbGV0dGVyJnV0bV9jYW1wYWlnbj0yMDIxLTA3LTI1JTIwW3VzLXdlc3QtY2FuXSUyMFdlZWtseSUyME5ld3NsZXR0ZXImdXRtX2NvbnRlbnQ9bWFya2V0aW5nJnV0bV90ZXJtPTI0NTI5MTM4/5f1ed0866577643680212e36C0cbf7e8e>
#
# One of FastCompany's Most Innovative Education Companies
#
#    Manage your Preferences <https://link.generalassemb.ly/oc/5f1ed0866577643680212e36elqsy.1u1p/39d8e89a> or Unsubscribe <https://link.generalassemb.ly/oc/5f1ed0866577643680212e36elqsy.1u1p/39d8e89a> General Assembly Inc., 915 Broadway, 3rd Floor New York, NY 10010View Privacy Policy <https://link.generalassemb.ly/click/24529138.>
# Saving HTML to Intro_to_customer_journey_mapping__securing_financial_safety__women_in_tech_breakfast/index.html
# ==========
# Date: Sun, 25 Jul 2021 17:30:19 +0000
# To: gordonpisciotta@gmail.com
# From: ZipRecruiter <alerts@ziprecruiter.com>
# Subject: Gordon Pisciotta, we've found new positions that match your search
# ==========
# Date: Sun, 25 Jul 2021 09:03:09 +0000
# From: Breaking 5G News <daily@email.breaking5gnews.com>
# To: gordon.pisciotta@gmail.com
# Subject: The Choice to Becoming Wealthy Is Yours, Today! | 25 July
# S New Techno The Choice to Becoming Wealthy Is Yours, Today - 2021-06-22
#
#
#
#
#
#
# July 25, 2021
#
#
#
# View in Browser
# <http://links.email.breaking5gnews.com/e/evib?_t=1bef442c89814adc8313f3f60c36f74d&_m=dc976c2d3d824d24be2d64df7a32c11b&_e=NxEqRAmEk9-6bkufYOcJe7h-RCVNnHnNki7wbDRkAp0i-QHGFnuNuqBgQFjQ8OZ4-HlfNywlpW3Q0KTeFJ0-eitPyKQi7dQL2vQEfsGWN6jjHkdfwS2Cgg9rO-a1Yaso>
#  |Unsubscribe
# <http://links.email.breaking5gnews.com/e/encryptedUnsubscribe?_r=1bef442c89814adc8313f3f60c36f74d&_s=dc976c2d3d824d24be2d64df7a32c11b&_t=NxEqRAmEk9-6bkufYOcJe7h-RCVNnHnNki7wbDRkAp0qU6PxoYFo-QRQXkNlf8CqKmnokt7bFr9fZjZnQP5AUoYIGs7kBgGq4POW1w2GElgbCvT4FOib2d8x1bDxGIMzs0Z9fQx1S31351BqBRJNywnAaZkcpUS4Y9DcGjhq5809K_8Sqv7YlWyjIaVAYAKA>
#
#
#
#
#  <https://breaking5gnews.com/>
#
# Below is a message from our partners that we thought you'd enjoy:
#
#
#
#
#
# The Choice to Becoming Wealthy Is Yours, Today
#
# The 500% Portfolio
# <https://thewebinarlinks.com/techno?s1=gordon.pisciotta@gmail.com>
#
#
#
#  <https://thewebinarlinks.com/techno?s1=gordon.pisciotta@gmail.com>
#
#
#
# Big and profitable technology disruptions ALWAYS happen from the outside.
#
# Let me explain…
#
# Netflix was not invented by Blockbuster.
#
# None of the TV networks came up with the idea for YouTube.
#
# And not a single hotel chain had anything to do with Airbnb.
#
# For the biggest gains, you need to own the fastest-growing, most disruptive,
# and most profitable “outsider” tech companies available in the markets today.
#
# And “the secret” to these riches and potentially owning a 500% portfolio lies
# within these numbers:
#
# 94027.
#
# If you don’t know what these numbers mean, that’s OK.
#
# The average American does not.
#
# But these numbers hold the secret to becoming super-wealthy today.
#
# If you’re even slightly curious about this, you’ll want to click the link
# below and watch an exclusive presentation.
#
# After watching, you’ll have the answer to “the secret.”
#
#
#
#  <https://thewebinarlinks.com/techno?s1=gordon.pisciotta@gmail.com>
#
#
#
# Eric Fry says most analysts will never find a single 1,000% winner their
# entire career. He’s already found 40 and explains how tohere
# <https://thewebinarlinks.com/techno?s1=gordon.pisciotta@gmail.com>.
#
#
#
# Click Here to Learn More
# <https://thewebinarlinks.com/techno?s1=gordon.pisciotta@gmail.com>
#
#
#
#
#
#
#
#
# This email was sent to gordon.pisciotta@gmail.com because you made a great
# decision to receive our Digest Daily.
#
#  To ensure you keep receiving our emails, be sure to white list us
# <https://breaking5gnews.com/whitelisting/>
#  © 2020 Breaking 5G News. All Rights Reserved.
#  10940 Parallel Pkwy Ste K, Kansas City, KS 66109
# Privacy Policy <https://breaking5gnews.com/privacy-policy/> | Unsubscribe
# <http://links.email.breaking5gnews.com/e/encryptedUnsubscribe?_r=1bef442c89814adc8313f3f60c36f74d&_s=dc976c2d3d824d24be2d64df7a32c11b&_t=NxEqRAmEk9-6bkufYOcJe7h-RCVNnHnNki7wbDRkAp0qU6PxoYFo-QRQXkNlf8CqKmnokt7bFr9fZjZnQP5AUoYIGs7kBgGq4POW1w2GElgbCvT4FOib2d8x1bDxGIMzs0Z9fQx1S31351BqBRJNywnAaZkcpUS4Y9DcGjhq5809K_8Sqv7YlWyjIaVAYAKA>
#
#
#
# Saving HTML to The_Choice_to_Becoming_Wealthy_Is_Yours__Today____25_July/index.html
# ==========
# Date: Sat, 24 Jul 2021 22:48:34 +0000
# To: gordonpisciotta@gmail.com
# From: ZipRecruiter <alerts@ziprecruiter.com>
# Subject: Gordon Pisciotta, ECLIPSE RTO, LLC may want to hire you
# ==========
# Date: Sat, 24 Jul 2021 21:22:58 +0000
# To: Gordon.pisciotta@gmail.com
# From: ZipRecruiter <alerts@ziprecruiter.com>
# Subject: FINANCIAL ANALYST jobs in DENVER as high as $90,000/yr
# ==========
# To: gordonpisciotta@gmail.com
# Date: Sat, 24 Jul 2021 13:01:06 +0000
# Subject: 9 MUST Own Growth Stocks for 2021
# From: "StockNews.com" <contact@stocknews.com>
# ==========
# Date: Sat, 24 Jul 2021 13:00:00 +0000 (UTC)
# From: Medium Daily Digest <noreply@medium.com>
# To: gordonpisciotta@gmail.com
# Subject: How to research a potential stock investment opportunity | Ali Kokaz in DataDrivenInvestor
# Stories for Gordon Pisciotta
# @gordonpisciotta (https://medium.com/@gordonpisciotta?source=email-2defc5fb1e7b-1627114194710-digest.reader-------------------------bcd2116b_528e_468e_94e7_baa2988d4848)
# ·Member (https://medium.com/@gordonpisciotta?source=email-2defc5fb1e7b-1627114194710-digest.reader-------------------------bcd2116b_528e_468e_94e7_baa2988d4848)
#
# From your following
# Edit who you follow (https://medium.com/me/following/people?source=email-2defc5fb1e7b-1627114194710-digest.reader-------------------------bcd2116b_528e_468e_94e7_baa2988d4848-31)
#
# Ali Kokaz (https://medium.com/@ali-kokaz?source=email-2defc5fb1e7b-1627114194710-digest.reader-32881626c9c9-fc26a447a67a----0-1------------------bcd2116b_528e_468e_94e7_baa2988d4848-31-ace5112e_73e3_4ddf_930a_38fc49be9b6a)
#  in DataDrivenInvestor·9 min read
#
# How to research a potential stock investment opportunity
#
# How to research opportunities like a finance pro, and the sources to use
#
# Mohammed Ayar (https://medium.com/@ayarmohammed96?source=email-2defc5fb1e7b-1627114194710-digest.reader-7f60cf5620c9-40ec00408eba----1-1------------------bcd2116b_528e_468e_94e7_baa2988d4848-31-ace5112e_73e3_4ddf_930a_38fc49be9b6a)
#  in Towards Data Science·8 min read
#
# How to Quickly Become a Data Scientist
#
# Compress X years of work into X months
#
# Chanin Nantasenamat in Data Professor (https://medium.com/data-professor?source=email-2defc5fb1e7b-1627114194710-digest.reader-ed69648d10b2-29101cb55c4b----2-2------------------bcd2116b_528e_468e_94e7_baa2988d4848-31-9bfcf221_0892_484a_b9df_90be1ca94aa6)
# ·3 min read
#
# Sarit Maitra·10 min read
#
# Trend Following Return & Optimization Technique of Capital Distribution
#
# Capital allocation with Convex Optimization, Kelly's Criterion & Markowitz Efficient Frontier (https://medium.com/@data-professor/day-14-of-the-66-days-of-data-29101cb55c4b?source=email-2defc5fb1e7b-1627114194710-digest.reader-ed69648d10b2-29101cb55c4b----2-2------------------bcd2116b_528e_468e_94e7_baa2988d4848-31-9bfcf221_0892_484a_b9df_90be1ca94aa6)
#
# Ankit Gupta (https://medium.com/@ankitgupta_974?source=email-2defc5fb1e7b-1627114194710-digest.reader-7219b4dc6c4c-9e36186d4b2----4-1------------------bcd2116b_528e_468e_94e7_baa2988d4848-31-ace5112e_73e3_4ddf_930a_38fc49be9b6a)
#  in Analytics Vidhya·4 min read
#
# The Top and Best Content of Machine Learning ,Deep Learning, Artificial…
#
# This Medium article especially for beginners who want to start build career in Machine Learning/Deep Learning…
#
# Dr. Dataman in Dataman in AI (https://medium.com/dataman-in-ai?source=email-2defc5fb1e7b-1627114194710-digest.reader-f1a98d28da9b-7e39d428c01d----5-2------------------bcd2116b_528e_468e_94e7_baa2988d4848-31-9bfcf221_0892_484a_b9df_90be1ca94aa6)
# ·6 min read
#
# Following the Data Science Process
#
# I am an amateur cook so I always subscribe to the youtube channels of professional chefs. I need the Step…
#
# Today's highlights
#
# How To Get Stock Quotes From Indexes With Python
#
# Retrieve a list of stocks with Python.
#
# Ilona D. (https://medium.com/@ilonacodes?source=email-2defc5fb1e7b-1627114194710-digest.reader-32881626c9c9-4818a5954642----0-83------------------bcd2116b_528e_468e_94e7_baa2988d4848-1-cceabf1c_e886_44fd_8590_2cd5dbfb9857)
#  in DataDrivenInvestor (https://medium.com/datadriveninvestor?source=email-2defc5fb1e7b-1627114194710-digest.reader-32881626c9c9-4818a5954642----0-83------------------bcd2116b_528e_468e_94e7_baa2988d4848-1-cceabf1c_e886_44fd_8590_2cd5dbfb9857)
# ·4 min read
#
# The Sharpe Ratio You didn't Know
#
# Knowing the limitations of performance metrics and looking from different angles may sometimes save capitals!
#
# AAA Quants (https://medium.com/@aaaquants?source=email-2defc5fb1e7b-1627114194710-digest.reader-f5af2b715248-bcbaa76601f4----1-59------------------bcd2116b_528e_468e_94e7_baa2988d4848-1-cceabf1c_e886_44fd_8590_2cd5dbfb9857)
#  in The Startup (https://medium.com/swlh?source=email-2defc5fb1e7b-1627114194710-digest.reader-f5af2b715248-bcbaa76601f4----1-59------------------bcd2116b_528e_468e_94e7_baa2988d4848-1-cceabf1c_e886_44fd_8590_2cd5dbfb9857)
# ·8 min read
#
# AI in Finance: how to finally start to believe your backtests [3/3]
#
# Understanding strategy risk and the probability of overfitting: small numbers that change everything
#
# Alexandr Honchar (https://medium.com/@alexrachnog?source=email-2defc5fb1e7b-1627114194710-digest.reader-7f60cf5620c9-2f3b4d875842----2-59------------------bcd2116b_528e_468e_94e7_baa2988d4848-1-cceabf1c_e886_44fd_8590_2cd5dbfb9857)
#  in Towards Data Science (https://medium.com/towards-data-science?source=email-2defc5fb1e7b-1627114194710-digest.reader-7f60cf5620c9-2f3b4d875842----2-59------------------bcd2116b_528e_468e_94e7_baa2988d4848-1-cceabf1c_e886_44fd_8590_2cd5dbfb9857)
# ·8 min read
#
# Combining the RSI With the Fisher Transform in a Trading Strategy.
#
# Can the RSI and the Fisher Transform Provide Good Signals?
#
# Sofien Kaabar (https://medium.com/@kaabar-sofien?source=email-2defc5fb1e7b-1627114194710-digest.reader-9758482ba857-da87c4f81da7----3-58------------------bcd2116b_528e_468e_94e7_baa2988d4848-1-cceabf1c_e886_44fd_8590_2cd5dbfb9857)
#  in Geek Culture (https://medium.com/geekculture?source=email-2defc5fb1e7b-1627114194710-digest.reader-9758482ba857-da87c4f81da7----3-58------------------bcd2116b_528e_468e_94e7_baa2988d4848-1-cceabf1c_e886_44fd_8590_2cd5dbfb9857)
# ·15 min read
#
# In case you missed it
#
# From Analog to Digital and Back
#
# Bits are the new electrons. The nature of analog computing is to take control.
#
# George Dyson (https://medium.com/@George_Dyson?source=email-2defc5fb1e7b-1627114194710-digest.reader-444d13b52878-10b359350b68----0-71------------------bcd2116b_528e_468e_94e7_baa2988d4848-27-3f7de952_b2a9_4a28_9dbb_b522fa29de7f)
#  in OneZero (https://medium.com/one-zero?source=email-2defc5fb1e7b-1627114194710-digest.reader-444d13b52878-10b359350b68----0-71------------------bcd2116b_528e_468e_94e7_baa2988d4848-27-3f7de952_b2a9_4a28_9dbb_b522fa29de7f)
# ·10 min read
#
# Machine Learning for Predicting The Unknown
#
# An interview with data scientist, Courtenay Cotton.
#
# Joanne McNeil  (https://medium.com/@jomc?source=email-2defc5fb1e7b-1627114194710-digest.reader--129d7f56b1e3----1-71------------------bcd2116b_528e_468e_94e7_baa2988d4848-27-3f7de952_b2a9_4a28_9dbb_b522fa29de7f)
# ·6 min read
#
# Which Businesses Should Reopen First? A New MIT Study Has Answers.
#
# As states plan to let businesses reopen, here's a data-driven approach to determine who should be first in…
#
# Kaushik Viswanath (https://medium.com/@kvish?source=email-2defc5fb1e7b-1627114194710-digest.reader-7b6769f2748b-2946499eaa46----2-71------------------bcd2116b_528e_468e_94e7_baa2988d4848-27-3f7de952_b2a9_4a28_9dbb_b522fa29de7f)
#  in Marker (https://medium.com/marker?source=email-2defc5fb1e7b-1627114194710-digest.reader-7b6769f2748b-2946499eaa46----2-71------------------bcd2116b_528e_468e_94e7_baa2988d4848-27-3f7de952_b2a9_4a28_9dbb_b522fa29de7f)
# ·8 min read
#
# Quick reads
#
# The Danger of Using Machine Learning in Trading Strategies
#
# ML doesn't fix everything.
#
# Mika Yeap (https://medium.com/@myika?source=email-2defc5fb1e7b-1627114194710-digest.reader-120491c074b5-26b8b5f0553b----0-72------------------bcd2116b_528e_468e_94e7_baa2988d4848-28-)
#  in Chartmaster (https://medium.com/chartmaster?source=email-2defc5fb1e7b-1627114194710-digest.reader-120491c074b5-26b8b5f0553b----0-72------------------bcd2116b_528e_468e_94e7_baa2988d4848-28-)
# ·3 min read
#
# Using LSTM's to Predict Future Stock Prices
#
# Model Developed in Python using SciKitLearn and Keras
#
# SFHS ML Club (https://medium.com/@sfhsmlclub?source=email-2defc5fb1e7b-1627114194710-digest.reader-aded347a067a-61f4458fc860----1-72------------------bcd2116b_528e_468e_94e7_baa2988d4848-28-)
#  in Visionary Hub (https://medium.com/visionary-hub?source=email-2defc5fb1e7b-1627114194710-digest.reader-aded347a067a-61f4458fc860----1-72------------------bcd2116b_528e_468e_94e7_baa2988d4848-28-)
# ·4 min read
#
# Modern Portfolio Theory-Effect of Diversification on the Optimal…
#
# In the previous installments, we presented the concept of Modern Portfolio Theory. We also provided an…
#
# Harbourfront Technologies (https://medium.com/@derivvaluation?source=email-2defc5fb1e7b-1627114194710-digest.reader--8d9660e5547e----2-72------------------bcd2116b_528e_468e_94e7_baa2988d4848-28-)
# ·3 min read
#
# Based on your reading history
#
# Introduction to Time Series - Trend Decomposition with Python
#
# Multipart series on time series analysis with Python applied to financial datasets
#
# Amir Nejad (https://medium.com/@amirnejad?source=email-2defc5fb1e7b-1627114194710-digest.reader-eb552617698a-b54a29f8e038----0-59------------------bcd2116b_528e_468e_94e7_baa2988d4848-16-57108480_53eb_47ce_b1e2_449a9d89fbe1)
#  in QuantJam (https://medium.com/quantjam?source=email-2defc5fb1e7b-1627114194710-digest.reader-eb552617698a-b54a29f8e038----0-59------------------bcd2116b_528e_468e_94e7_baa2988d4848-16-57108480_53eb_47ce_b1e2_449a9d89fbe1)
# ·6 min read
#
# Algorithmic Trading with the Know Sure Thing indicator in Python
#
# A complete guide on using and implementing the KST indicator in python
#
# Nikhil Adithyan (https://medium.com/@nikhiladithyan?source=email-2defc5fb1e7b-1627114194710-digest.reader-29038077e4c6-68860a38a879----1-58------------------bcd2116b_528e_468e_94e7_baa2988d4848-16-57108480_53eb_47ce_b1e2_449a9d89fbe1)
#  in CodeX (https://medium.com/codex?source=email-2defc5fb1e7b-1627114194710-digest.reader-29038077e4c6-68860a38a879----1-58------------------bcd2116b_528e_468e_94e7_baa2988d4848-16-57108480_53eb_47ce_b1e2_449a9d89fbe1)
# ·20 min read
#
# Top Python trading packages for 2021
#
# Trading with python
#
# Shyam BV (https://medium.com/@bvshyam?source=email-2defc5fb1e7b-1627114194710-digest.reader-5da2254e0df2-f6165f2674a8----2-58------------------bcd2116b_528e_468e_94e7_baa2988d4848-16-57108480_53eb_47ce_b1e2_449a9d89fbe1)
#  in Code Sprout (https://medium.com/code-sprout?source=email-2defc5fb1e7b-1627114194710-digest.reader-5da2254e0df2-f6165f2674a8----2-58------------------bcd2116b_528e_468e_94e7_baa2988d4848-16-57108480_53eb_47ce_b1e2_449a9d89fbe1)
# ·5 min read
#
# Best in Cryptocurrency
#
# I'm All Shook Up
#
# (Any views expressed in the below are the personal views of the author and should not form the basis for…
#
# Arthur Hayes (https://medium.com/@cryptohayes?source=email-2defc5fb1e7b-1627114194710-digest.reader--ba2559081ee0----0-49----------9213b0063bcc--------bcd2116b_528e_468e_94e7_baa2988d4848-11-)
# ·12 min read
#
# Bitcoiners Are Desperate For One Last Pump So They Can Dump
#
# They're revealing crypto trading was a scam the whole time
#
# Jared A. Brock (https://medium.com/@jaredabrock?source=email-2defc5fb1e7b-1627114194710-digest.reader-2c40f2a0223e-31f2e58d7025----1-49----------9213b0063bcc--------bcd2116b_528e_468e_94e7_baa2988d4848-11-)
#  in Surviving Tomorrow (https://medium.com/surviving-tomorrow?source=email-2defc5fb1e7b-1627114194710-digest.reader-2c40f2a0223e-31f2e58d7025----1-49----------9213b0063bcc--------bcd2116b_528e_468e_94e7_baa2988d4848-11-)
# ·5 min read
#
# Best in Money
#
# 6 Money Rules I'll Follow Until I Die
#
# These are the financial rules I refuse to break.
#
# Lauren Como (https://medium.com/@laurencomo?source=email-2defc5fb1e7b-1627114194710-digest.reader-9350d123beb6-81510a82fe59----0-49----------1d98b3a9a871--------bcd2116b_528e_468e_94e7_baa2988d4848-11-)
#  in Making of a Millionaire (https://medium.com/makingofamillionaire?source=email-2defc5fb1e7b-1627114194710-digest.reader-9350d123beb6-81510a82fe59----0-49----------1d98b3a9a871--------bcd2116b_528e_468e_94e7_baa2988d4848-11-)
# ·7 min read
#
# See more of what you like and less of what you don't.
# Control your recommendations (https://medium.com/me/missioncontrol?source=email-2defc5fb1e7b-1627114194710-digest.reader-------------------------bcd2116b_528e_468e_94e7_baa2988d4848)
#
# Read or write from anywhere.
#
# Sent by Medium (https://medium.com/?source=email-2defc5fb1e7b-1627114194710-digest.reader-------------------------bcd2116b_528e_468e_94e7_baa2988d4848)
# ·P.O. Box 602, San Francisco, CA 94104-0602
# Unsubscribe (https://medium.com/me/email-settings/2defc5fb1e7b/d64a352af713?type=social&source=email-2defc5fb1e7b-1627114194710-digest.reader-------------------------bcd2116b_528e_468e_94e7_baa2988d4848)
#  from this type of email·Switch to the Weekly Digest (https://medium.com/me/email-settings/2defc5fb1e7b/d64a352af713?type=social&preference=2&source=email-2defc5fb1e7b-1627114194710-digest.reader-------------------------bcd2116b_528e_468e_94e7_baa2988d4848)
# ·Careers (https://medium.com/jobs-at-medium/work-at-medium-959d1a85284e?source=email-2defc5fb1e7b-1627114194710-digest.reader-------------------------bcd2116b_528e_468e_94e7_baa2988d4848)
# ·Help Center (https://help.medium.com/hc/en-us?source=email-2defc5fb1e7b-1627114194710-digest.reader-------------------------bcd2116b_528e_468e_94e7_baa2988d4848)
# ...
#
# Simple Physics Animations Using VPython (https://towardsdatascience.com/simple-physics-animations-using-vpython-1fce0284606?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Zhiheng Jiang (https://medium.com/u/fd32045f68d4)
#
# Hands-On Tutorials
# Similarity Encoding for Dirty Categories Using dirty_cat (https://towardsdatascience.com/similarity-encoding-for-dirty-categories-using-dirty-cat-d9f0b581a552?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Khuyen Tran (https://medium.com/u/84a02493194a)
#
# How to Render a 3D Mesh and Convert It to a 2D Image Using PyTorch3D (https://towardsdatascience.com/how-to-render-3d-files-using-pytorch3d-ef9de72483f8?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Adele Kuzmiakova (https://medium.com/u/236969c3b5d9)
#
# Image Captions with Attention in TensorFlow, Step (https://towardsdatascience.com/image-captions-with-attention-in-tensorflow-step-by-step-927dad3569fa?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Step by Ketan Doshi (https://medium.com/u/54f9ca55ed47)
#
# Deep Dives
# Who's Who and What's What: Advances in Biomedical Named-Entity Recognition (BioNER) (https://towardsdatascience.com/whos-who-and-what-s-what-advances-in-biomedical-named-entity-recognition-bioner-c42a3f63334c?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Sybren Jansen (https://medium.com/u/7da425256f5d)
#
# Enhancing Autoencoders with Memory Modules for Anomaly Detection (https://towardsdatascience.com/enhancing-autoencoders-with-memory-modules-for-anomaly-detection-692dfad5e4fb?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Varun Menon (https://medium.com/u/e80621703842)
#
# A Comparison of Synthetic vs. Human Labeled Dataset to Train a UNet Segmentation Model (https://towardsdatascience.com/a-comparison-of-synthetic-vs-human-labeled-dataset-to-train-a-unet-segmentation-model-10588f8d9c12?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Aaron Soellinger (https://medium.com/u/e7d1a49e6867)
#
# Thoughts and Theory
# I Forgot How to Spellcheck (https://towardsdatascience.com/i-forgot-how-to-spellcheck-fb8f766ede2b?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Victor Shepelev (https://medium.com/u/138ad8656987)
#
# Get Started with MLOps (https://towardsdatascience.com/get-started-with-mlops-fd7062cab018?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Mathias Gruber (https://medium.com/u/bd465150179d)
#
# Strategists: Stop Obsessing about Averages (https://towardsdatascience.com/strategists-stop-obsessing-about-averages-923bc5f57ca0?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
#  by Roger Martin (https://medium.com/u/3f12bb07b95d)
#
# From The Variable
# A newsletter by Towards Data Science
# Every Thursday, the Variable delivers the very best of Towards Data Science: from hands-on tutorials and cutting-edge research to original features you don't want to miss.
# More from this newsletter (https://medium.com/towards-data-science/newsletters/the-variable?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869---780c689a8400-----d6fe9076899--footer)
#
# View in browser (https://medium.com/towards-data-science/what-problem-is-your-data-solving-f39ae1daa6e9?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899)
# ---
# Sent by Medium, P.O. Box 602, San Francisco, CA 94104-0602
# To unsubscribe, visit https://medium.com/me/email-settings/2defc5fb1e7b/1827173b87dc?source=email-2defc5fb1e7b-1620913014021-newsletter.v3-7f60cf5620c9------------------------745fbf60_c72e_4f85_8e58_961b22c18869--------d6fe9076899&type=newsletterV3&collectionId=7f60cf5620c9&newsletterId=780c689a8400&newsletterV3Id=d6fe9076899
#
# Saving HTML to What_Problem_Is_Your_Data_Solving_/index.html
# ==========
# To: gordon.pisciotta@gmail.com
# Date: Thu, 13 May 2021 11:06:58 +0000
# Subject: Create & Build Your Own Toys With This 3D Printer
# From: Popular Science Shop <shop@email.stackcommerce.com>
# This toybox 3D printing bundle is 32% off right now. Popular Science
#  <https://shop.popsci.com/>
#
#
#  <https://shop.popsci.com/sales/toybox-3d-printer?utm_term=featuredeal1>
#
#
# Toybox 3D Printer Deluxe Bundle (32% OFF)
#  <https://shop.popsci.com/sales/toybox-3d-printer?utm_term=featuredeal1>
#
# This Beginner-Friendly Printer Lets Your Kids Design & Create Their Own Toys
# Right at Home
#
#
# <https://shop.popsci.com/sales/the-electrical-circuits-engineering-certification-bundle?utm_term=featuredeal2>
#
#
# The Electrical & Circuits Engineering Certification Bundle (95% OFF)
#
# <https://shop.popsci.com/sales/the-electrical-circuits-engineering-certification-bundle?utm_term=featuredeal2>
#
# Power Up Your Electrical Engineering Career with 34 Hours of Comprehensive
# Content on Electric Circuits, Machines, Power Generation, Electronics, & More
#
#
# <https://shop.popsci.com/sales/bug-bite-thing-insect-bite-sting-relief-suction-tool-bundle-of-2?utm_term=featuredeal3>
#
#
# Bug Bite Thing® Insect Bite/Sting Relief Suction Tool: 2-Pack
#
# <https://shop.popsci.com/sales/bug-bite-thing-insect-bite-sting-relief-suction-tool-bundle-of-2?utm_term=featuredeal3>
#
# Enter Coupon BUGBITE6 for Discount! Alleviate Pain, Itching & Swelling Caused
# by Bug Bites with This Easy-to-Use Suction Tool — No Cream, No Chemicals,
# Kid-Friendly
#
#
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/0?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide1>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/1?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide2>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/2?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide3>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/3?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide4>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/4?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide5>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/5?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywideamplify6>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/6?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywideamplify7>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/7?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywideamplify8>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/8?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide9>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/9?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide10>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/10?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide11>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/11?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide12>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/12?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide13>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/13?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide14>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/14?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide15>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/15?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide16>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/16?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide17>
#
# <https://em.dynamicyield.com/emclk/8775897/10405/106762/25916/18/17?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dywide18>
#
#
# <https://shop.popsci.com/best-sellers?sort=best_sellers&utm_term=recommendedbanner>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/0?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub1>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/1?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub2>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/2?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub3>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/3?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub4>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/4?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub5>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/5?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub6>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/6?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub7>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/7?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub8>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/8?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub9>
#
# <https://em.dynamicyield.com/emclk/8775897/10398/106763/25916/10/9?dy_ts=20210513&dy_locale=143&dy_cuid=4e0430778ff1a3b6a4f55297544c25c6f1ed80cfc0dd384ced76125f76dd9b16&dy_version=20210513_Tech_DailyDeals_19738_Toybox3DPrinterDeluxeBundle_3Handpicked_a0x1P000004ezFr&utm_term=dysub10>
#
#
#
# <https://stackmedia.io/?utm_source=1a2b5cv5860&utm_medium=0a0b0ca7100&utm_term=scsf-490668&utm_content=101-a0x1P000004f4ym&pub_id=4088>
#
#
#  <https://shop.popsci.com/user/credits> <https://shop.popsci.com/user/credits>
# <https://shop.popsci.com/user/credits>
#  <https://www.facebook.com/PopSci/>  <https://twitter.com/PopSci>
# <https://www.pinterest.com/>
#
#
# Popular Science Shop is powered by StackCommerce <https://stackcommerce.com/>
#
#
#
# unsubscribe from this list
# <https://link.email.stackcommerce.com/e/eh?_t=40bd9518025f4054bd691f353eefaddb&_m=601e2a6da334489fbeff7e4a8f8e5e4c&_e=h8paGnWXsYokOf2j-ZIk55d6ez3ASknRb5LqaYuqkVPGpFdDCy39XdCxZ6izZoZ8clUytQykJ3N5BtR3GVc1lwZsfxlym9shPaUHev91p_mnzg46Q1Az6OVv1lMtu4eFW99U-ojgulw3TcNSriFrlaSNBDzYBZx-uRAPu8Q0nWRDBZlKBBXHLPmS-CCejovxTkh4_bxk3dl5pf4S4vjJ41BEvT0vb8zoeyCdiQKJBNZ_x-ArIOcCXI7a3HkpTWN9lZbovIiXDYYSd5sj1DTdFPWW3Mx3IH057bs2PqRjO7iqmNBEI2sjauQGJTuQQs2qyeLzAAtU7HvIsusm4gQ9IA%3D%3D>
#
# 21 Market Street | Venice, CA 90291 | United States
# © 2021 StackCommerce
# *Some exclusions may apply. Coupons must be used within 48 hours and not valid
# on Pay What You Want deals. Cannot combine promos with account credit, price
# drops or other promotions.
# Saving HTML to Create___Build_Your_Own_Toys_With_This_3D_Printer/index.html
# ==========
# Date: Wed, 12 May 2021 23:49:21 +0000 (UTC)
# From: Glassdoor Jobs <noreply@glassdoor.com>
# To: gordonpisciotta@gmail.com
# Subject: Senior Data Scientist at Cloud Agronomics and 9 more jobs in Denver, CO for you. Apply Now.
# ==========

# %%
def mark_as_read(service, query):
    messages_to_mark = search_messages(service, query)
    return service.users().messages().batchModify(
      userId='me',
      body={
          'ids': [ msg['id'] for msg in messages_to_mark ],
          'removeLabelIds': ['UNREAD']
      }
    ).execute()

def mark_as_unread(service, query):
    messages_to_mark = search_messages(service, query)
    return service.users().messages().batchModify(
        userId='me',
        body={
            'ids': [ msg['id'] for msg in messages_to_mark ],
            'addLabelIds': ['UNREAD']
        }
    ).execute()

# %%
mark_as_read(
    service, 
    "Google"
)

# search query by sender/receiver
mark_as_unread(
    service, 
    "gordon.d.pisciotta@gmail.com",
    )
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-12-ec49ce0d5dd0> in <module>
#       1 mark_as_read(
#       2     service,
# ----> 3     "Google"
#       4 )
#       5
#
# <ipython-input-10-15d7132a8574> in mark_as_read(service, query)
#       5       body={
#       6           'ids': [ msg['id'] for msg in messages_to_mark ],
# ----> 7           'removeLabelIds': ['UNREAD']
#       8       }
#       9     ).execute()
#
# ~/anaconda3/lib/python3.7/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     130                     logger.warning(message)
# --> 131             return wrapped(*args, **kwargs)
#     132
#     133         return positional_wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     935             callback(resp)
#     936         if resp.status >= 300:
# --> 937             raise HttpError(resp, content, uri=self.uri)
#     938         return self.postproc(resp, content)
#     939
#
# HttpError: <HttpError 400 when requesting https://gmail.googleapis.com/gmail/v1/users/me/messages/batchModify? returned "Number of ids cannot exceed 1000". Details: "[{'message': 'Number of ids cannot exceed 1000', 'domain': 'global', 'reason': 'invalidArgument'}]">

# %%
def delete_messages(service, query):
    messages_to_delete = search_messages(service, query)
    # it's possible to delete a single message with the delete API, like this:
    # service.users().messages().delete(userId='me', id=msg['id'])
    # but it's also possible to delete all the selected messages with one query, batchDelete
    return service.users().messages().batchDelete(
      userId='me',
      body={
          'ids': [ msg['id'] for msg in messages_to_delete]
      }
    ).execute()

# %%
delete_messages(service, "Google Alerts")
